# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
import os
from subprocess import check_output
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from pandas.plotting import lag_plot
from pandas import datetime
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARMA
warnings.filterwarnings('ignore')

import warnings
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
# !pip install yahoofinancials
# Out:
# Requirement already satisfied: yahoofinancials in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (1.6)
# Requirement already satisfied: beautifulsoup4 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from yahoofinancials) (4.9.3)
# Requirement already satisfied: pytz in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from yahoofinancials) (2020.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from beautifulsoup4->yahoofinancials) (2.0.1)

# %%
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
tesla = yf.download('TSLA', 
                      start='2019-01-01', 
                      end='2021-06-15', 
                      progress=False,
)
tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2018-12-31  67.557999  67.842003  65.052002  66.559998  66.559998  31511500
# 2019-01-02  61.220001  63.026001  59.759998  62.023998  62.023998  58293000
# 2019-01-03  61.400002  61.880001  59.476002  60.071999  60.071999  34826000
# 2019-01-04  61.200001  63.599998  60.546001  63.537998  63.537998  36970500
# 2019-01-07  64.344002  67.348000  63.549999  66.991997  66.991997  37756000

# %%
tesla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-06-08  623.010010  623.090027  595.500000  603.590027  603.590027
# 2021-06-09  602.169983  611.789978  597.630005  598.780029  598.780029
# 2021-06-10  603.880005  616.590027  600.500000  610.119995  610.119995
# 2021-06-11  610.229980  612.559998  601.520020  609.890015  609.890015
# 2021-06-14  612.229980  625.489990  609.179993  617.690002  617.690002
#
#               Volume
# Date
# 2021-06-08  26053400
# 2021-06-09  16584600
# 2021-06-10  23919600
# 2021-06-11  16205300
# 2021-06-14  20424000

# %%
type(tesla)
# Out:
# pandas.core.frame.DataFrame

# %%
print(tesla.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 618 entries, 2018-12-31 to 2021-06-14
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       618 non-null    float64
#  1   High       618 non-null    float64
#  2   Low        618 non-null    float64
#  3   Close      618 non-null    float64
#  4   Adj Close  618 non-null    float64
#  5   Volume     618 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 33.8 KB
# None

# %%
tesla.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
tesla_close = tesla['Close']

# %%
tesla_close.head()
# Out:
# Date
# 2018-12-31    66.559998
# 2019-01-02    62.023998
# 2019-01-03    60.071999
# 2019-01-04    63.537998
# 2019-01-07    66.991997
# Name: Close, dtype: float64

# %%
tesla_close.index
# Out:
# DatetimeIndex(['2018-12-31', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10',
#                '2019-01-11', '2019-01-14',
#                ...
#                '2021-06-01', '2021-06-02', '2021-06-03', '2021-06-04',
#                '2021-06-07', '2021-06-08', '2021-06-09', '2021-06-10',
#                '2021-06-11', '2021-06-14'],
#               dtype='datetime64[ns]', name='Date', length=618, freq=None)

# %%
tesla_close.describe().T
# Out:
# count    618.000000
# mean     269.335323
# std      259.079347
# min       35.793999
# 25%       56.147000
# 50%      146.194000
# 75%      442.052498
# max      883.090027
# Name: Close, dtype: float64

# %%
tesla_close.plot(figsize=(10,8),color='green',label='Tesla Closing Price')
plt.legend(loc='upper left');

# %%
type(tesla_close)
# Out:
# pandas.core.series.Series

# %%
tesla_close.rolling(12).mean().plot(label='12 Month Rolling Mean',figsize=(10,8))
tesla_close.rolling(12).std().plot(label='12 Month Rolling STD')
tesla_close.plot(label='Tesla Closing Price')
plt.legend();

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomp = seasonal_decompose(tesla_close,model = 'multiplicative', period=12)  
fig = plt.figure()  
fig = decomp.plot()  
fig.set_size_inches(15, 8)

# %% [markdown]
# ### Dicky Fuller Test

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(tesla_close)

# %%
result
# Out:
# (-0.39516921571520924,
#  0.9109022262469548,
#  19,
#  598,
#  {'1%': -3.4413325959192393,
#   '5%': -2.86638530474078,
#   '10%': -2.569350430308386},
#  4994.534013517548)

# %%
def adf_check(tesla_close):
    
    result=adfuller(tesla_close)
    print(" Augmented Dicky-Fuller Test")
    labels = ['ADF Test Statistic','p-value','# of lags','Num of Obseravtions used']
    
    for value,label in zip(result,labels):
        print(label+" : "+str(value))
        
    if result[1]<=0.05:
        print("Strong evidence against null hypothesis")
        print("Reject null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against null hypothesis")
        print("Fail to reject null hypothesis")
        print("Data has a unit root, it is non-stationary")

# %%
adf_check(tesla_close)
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -0.39516921571520924
# p-value : 0.9109022262469548
# # of lags : 19
# Num of Obseravtions used : 598
# Weak evidence against null hypothesis
# Fail to reject null hypothesis
# Data has a unit root, it is non-stationary

# %%
tesla['First Difference'] = tesla_close - tesla_close.shift(1)

# %%
tesla['First Difference'].plot(figsize=(10,8));

# %%
adf_check(tesla['First Difference'].dropna())
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -5.710809075813253
# p-value : 7.30717287803096e-07
# # of lags : 18
# Num of Obseravtions used : 598
# Strong evidence against null hypothesis
# Reject null hypothesis
# Data has no unit root and is stationary

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(tesla['First Difference'].iloc[13:], lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(tesla['First Difference'].iloc[13:], lags=40, ax=ax2)

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
from pmdarima.arima import auto_arima

# %%
#Modeling
# Build Model
model = ARIMA(tesla_close, order=(1, 0, 1))  
results = model.fit()  
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  618
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -2576.779
# Date:                Fri, 08 Apr 2022   AIC                           5161.558
# Time:                        10:17:50   BIC                           5179.264
# Sample:                             0   HQIC                          5168.441
#                                 - 618
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        269.4941    402.684      0.669      0.503    -519.752    1058.740
# ar.L1          0.9986      0.002    437.327      0.000       0.994       1.003
# ma.L1         -0.0771      0.022     -3.524      0.000      -0.120      -0.034
# sigma2       242.7268      6.240     38.900      0.000     230.497     254.957
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              1774.26
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):             189.82   Skew:                             0.37
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.27
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
results.resid
# Out:
# Date
# 2018-12-31   -202.934120
# 2019-01-02     -4.868501
# 2019-01-03     -2.613080
# 2019-01-04      2.973933
# 2019-01-07      3.397576
#                  ...
# 2021-06-08     -0.427046
# 2021-06-09     -4.379382
# 2021-06-10     11.459123
# 2021-06-11      1.126297
# 2021-06-14      8.359130
# Length: 618, dtype: float64

# %%
results.resid.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
results.resid.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
results

# %%
tesla['forecast'] = results.predict(start = 600, end= 618, dynamic= True)  
tesla[['Close','forecast']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
tesla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-06-08  623.010010  623.090027  595.500000  603.590027  603.590027
# 2021-06-09  602.169983  611.789978  597.630005  598.780029  598.780029
# 2021-06-10  603.880005  616.590027  600.500000  610.119995  610.119995
# 2021-06-11  610.229980  612.559998  601.520020  609.890015  609.890015
# 2021-06-14  612.229980  625.489990  609.179993  617.690002  617.690002
#
#               Volume  First Difference  forecast
# Date
# 2021-06-08  26053400         -1.539978       NaN
# 2021-06-09  16584600         -4.809998       NaN
# 2021-06-10  23919600         11.339966       NaN
# 2021-06-11  16205300         -0.229980       NaN
# 2021-06-14  20424000          7.799988       NaN
