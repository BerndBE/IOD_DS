# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import statsmodels.api as sm
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\compat\pandas.py:61: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
df = yf.download('IBM', 
                      start='2008-01-01', 
                      end='2018-04-01', 
                      progress=False, 
                      interval='1mo'
)
df.head()
# Out:
#                   Open        High         Low       Close  Adj Close  \
# Date
# 2008-01-01  104.196938  104.196938   92.772469  102.399620  65.712219
# 2008-02-01  102.447418  111.500954   96.175911  108.852776  69.853378
# 2008-02-06         NaN         NaN         NaN         NaN        NaN
# 2008-03-01  108.852776  114.521988  106.883362  110.076485  70.908714
# 2008-04-01  110.133842  119.502869  108.852776  115.391968  74.332840
#
#                  Volume
# Date
# 2008-01-01  258909998.0
# 2008-02-01  176021717.0
# 2008-02-06          NaN
# 2008-03-01  187531272.0
# 2008-04-01  200923212.0

# %%
df.drop(['Open','High','Low','Adj Close','Volume'],axis=1,inplace=True)
df.head()
# Out:
#                  Close
# Date
# 2008-01-01  102.399620
# 2008-02-01  108.852776
# 2008-02-06         NaN
# 2008-03-01  110.076485
# 2008-04-01  115.391968

# %%
df.dropna(subset=['Close'],inplace=True)
df.head()
# Out:
#                  Close
# Date
# 2008-01-01  102.399620
# 2008-02-01  108.852776
# 2008-03-01  110.076485
# 2008-04-01  115.391968
# 2008-05-01  123.738052

# %%
df.tail()
# Out:
#                  Close
# Date
# 2017-11-01  147.198853
# 2017-12-01  146.673035
# 2018-01-01  156.500961
# 2018-02-01  148.977051
# 2018-03-01  146.682602

# %%
df.index
# Out:
# DatetimeIndex(['2008-01-01', '2008-02-01', '2008-03-01', '2008-04-01',
#                '2008-05-01', '2008-06-01', '2008-07-01', '2008-08-01',
#                '2008-09-01', '2008-10-01',
#                ...
#                '2017-06-01', '2017-07-01', '2017-08-01', '2017-09-01',
#                '2017-10-01', '2017-11-01', '2017-12-01', '2018-01-01',
#                '2018-02-01', '2018-03-01'],
#               dtype='datetime64[ns]', name='Date', length=123, freq=None)

# %%
df.describe().T
# Out:
#        count        mean       std        min         25%         50%  \
# Close  123.0  149.388612  30.16306  78.011475  123.532505  153.240921
#
#               75%         max
# Close  175.023903  203.919693

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
time_series = df['Close']

# %%
type(time_series)
# Out:
# pandas.core.series.Series

# %%
time_series.rolling(12).mean().plot(label='12 Month Rolling Mean',figsize=(10,8))
time_series.rolling(12).std().plot(label='12 Month Rolling STD')
time_series.plot(label='Close Price')
plt.legend();

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomp = seasonal_decompose(time_series)

# %%
fig=decomp.plot()
fig.set_size_inches(15,8)

# %%
df.head()
# Out:
#                  Close
# Date
# 2008-01-01  102.399620
# 2008-02-01  108.852776
# 2008-03-01  110.076485
# 2008-04-01  115.391968
# 2008-05-01  123.738052

# %% [markdown]
# ### Dicky Fuller Test
# Test if data is stationary or not

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(df['Close'])

# %%
result
# Out:
# (-1.8393461990185158,
#  0.3611096669221444,
#  0,
#  122,
#  {'1%': -3.4851223522012855,
#   '5%': -2.88553750045158,
#   '10%': -2.5795685622144586},
#  742.5271623573511)

# %%
def adf_check(time_series):
    
    result=adfuller(time_series)
    print(" Augmented Dicky-Fuller Test")
    labels = ['ADF Test Statistic','p-value','# of lags','Num of Obseravtions used']
    
    for value,label in zip(result,labels):
        print(label+" : "+str(value))
        
    if result[1]<=0.05:
        print("Strong evidence against null hypothesis")
        print("Reject null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against null hypothesis")
        print("Fail to reject null hypothesis")
        print("Data has a unit root, it is non-stationary")

# %%
adf_check(df['Close'])
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -1.8393461990185158
# p-value : 0.3611096669221444
# # of lags : 0
# Num of Obseravtions used : 122
# Weak evidence against null hypothesis
# Fail to reject null hypothesis
# Data has a unit root, it is non-stationary

# %%
df['First Difference'] = df['Close'] - df['Close'].shift(1)

# %%
df['First Difference'].plot();

# %%
adf_check(df['First Difference'].dropna())
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -11.521926003013878
# p-value : 4.020667090166686e-21
# # of lags : 0
# Num of Obseravtions used : 121
# Strong evidence against null hypothesis
# Reject null hypothesis
# Data has no unit root and is stationary

# %% [markdown]
# #### The above shows the data is stationary as p-value is < 0.05
# The below is just to show in case we need a second difference

# %%
df['Seasonal Difference'] = df['Close'] - df['Close'].shift(12)

# %%
df['Seasonal Difference'].plot();

# %%
adf_check(df['Seasonal Difference'].dropna())
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -1.2134576153139525
# p-value : 0.6677799595044898
# # of lags : 12
# Num of Obseravtions used : 98
# Weak evidence against null hypothesis
# Fail to reject null hypothesis
# Data has a unit root, it is non-stationary

# %%
df['Seasonal First Difference'] = df['First Difference'] - df['First Difference'].shift(12)

# %%
df['Seasonal Difference'].plot();

# %%
adf_check(df['Seasonal First Difference'].dropna())
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -4.4005769668318795
# p-value : 0.00029613550684252313
# # of lags : 11
# Num of Obseravtions used : 98
# Strong evidence against null hypothesis
# Reject null hypothesis
# Data has no unit root and is stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
fig_first = plot_acf(df['First Difference'].dropna())

# %%
fig_seasonal_first = plot_acf(df['Seasonal First Difference'].dropna())

# %%
result = plot_pacf(df['Seasonal First Difference'].dropna())
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
plot_acf(df['Seasonal First Difference'].dropna())
plot_pacf(df['Seasonal First Difference'].dropna())
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
help(ARIMA)
# Out:
# Help on class ARIMA in module statsmodels.tsa.arima_model:
#
# class ARIMA(ARMA)
#  |  ARIMA(*args, **kwargs)
#  |
#  |  ARIMA has been deprecated in favor of the new implementation
#  |
#  |  See Also
#  |  --------
#  |  statsmodels.tsa.arima.model.ARIMA
#  |      ARIMA models with a variety of parameter estimators
#  |  statsmodels.tsa.statespace.SARIMAX
#  |      SARIMAX models estimated using MLE
#  |
#  |  Method resolution order:
#  |      ARIMA
#  |      ARMA
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from ARMA:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
model = sm.tsa.statespace.SARIMAX(df['Close'],order=(0,1,0),seasonal_order=(1,1,1,12))
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:536: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:536: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
results = model.fit()

# %%
print(results.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                Close   No. Observations:                  123
# Model:             SARIMAX(0, 1, 0)x(1, 1, [1], 12)   Log Likelihood                -387.599
# Date:                              Tue, 19 Apr 2022   AIC                            781.199
# Time:                                      17:59:50   BIC                            789.300
# Sample:                                  01-01-2008   HQIC                           784.485
#                                        - 03-01-2018
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.0163      0.132      0.124      0.902      -0.242       0.275
# ma.S.L12      -0.9982     15.069     -0.066      0.947     -30.533      28.536
# sigma2        52.5259    787.104      0.067      0.947   -1490.169    1595.221
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.41
# Prob(Q):                              0.96   Prob(JB):                         0.81
# Heteroskedasticity (H):               1.25   Skew:                            -0.12
# Prob(H) (two-sided):                  0.50   Kurtosis:                         2.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
results.resid
# Out:
# Date
# 2008-01-01    102.399620
# 2008-02-01      6.453156
# 2008-03-01      1.223709
# 2008-04-01      5.315483
# 2008-05-01      8.346085
#                  ...
# 2017-11-01      0.072032
# 2017-12-01     -2.459047
# 2018-01-01      8.402902
# 2018-02-01    -11.593015
# 2018-03-01     -7.207104
# Length: 123, dtype: float64

# %%
results.resid.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
results.resid.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.shape
# Out:
# (123, 4)

# %%
df['forecast'] = results.predict(start=100,end=123)
df[['Close','forecast']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.tail()
# Out:
#                  Close  First Difference  Seasonal Difference  \
# Date
# 2017-11-01  147.198853         -0.086044            -7.887192
# 2017-12-01  146.673035         -0.525818           -12.017212
# 2018-01-01  156.500961          9.827927           -10.344162
# 2018-02-01  148.977051         -7.523911           -22.934998
# 2018-03-01  146.682602         -2.294449           -19.799240
#
#             Seasonal First Difference    forecast
# Date
# 2017-11-01                  -8.240921  147.126821
# 2017-12-01                  -4.130020  149.132081
# 2018-01-01                   1.673050  148.098059
# 2018-02-01                 -12.590836  160.570065
# 2018-03-01                   3.135757  153.889706

# %%
from pandas.tseries.offsets import DateOffset

# %%
future_dates = [df.index[-1]+DateOffset(months=x) for x in range(1,24)]

# %%
future_dates
# Out:
# [Timestamp('2018-04-01 00:00:00'),
#  Timestamp('2018-05-01 00:00:00'),
#  Timestamp('2018-06-01 00:00:00'),
#  Timestamp('2018-07-01 00:00:00'),
#  Timestamp('2018-08-01 00:00:00'),
#  Timestamp('2018-09-01 00:00:00'),
#  Timestamp('2018-10-01 00:00:00'),
#  Timestamp('2018-11-01 00:00:00'),
#  Timestamp('2018-12-01 00:00:00'),
#  Timestamp('2019-01-01 00:00:00'),
#  Timestamp('2019-02-01 00:00:00'),
#  Timestamp('2019-03-01 00:00:00'),
#  Timestamp('2019-04-01 00:00:00'),
#  Timestamp('2019-05-01 00:00:00'),
#  Timestamp('2019-06-01 00:00:00'),
#  Timestamp('2019-07-01 00:00:00'),
#  Timestamp('2019-08-01 00:00:00'),
#  Timestamp('2019-09-01 00:00:00'),
#  Timestamp('2019-10-01 00:00:00'),
#  Timestamp('2019-11-01 00:00:00'),
#  Timestamp('2019-12-01 00:00:00'),
#  Timestamp('2020-01-01 00:00:00'),
#  Timestamp('2020-02-01 00:00:00')]

# %%
future_df = pd.DataFrame(index=future_dates,columns=df.columns)

# %%
future_df
# Out:
#            Close First Difference Seasonal Difference  \
# 2018-04-01   NaN              NaN                 NaN
# 2018-05-01   NaN              NaN                 NaN
# 2018-06-01   NaN              NaN                 NaN
# 2018-07-01   NaN              NaN                 NaN
# 2018-08-01   NaN              NaN                 NaN
# 2018-09-01   NaN              NaN                 NaN
# 2018-10-01   NaN              NaN                 NaN
# 2018-11-01   NaN              NaN                 NaN
# 2018-12-01   NaN              NaN                 NaN
# 2019-01-01   NaN              NaN                 NaN
# 2019-02-01   NaN              NaN                 NaN
# 2019-03-01   NaN              NaN                 NaN
# 2019-04-01   NaN              NaN                 NaN
# 2019-05-01   NaN              NaN                 NaN
# 2019-06-01   NaN              NaN                 NaN
# 2019-07-01   NaN              NaN                 NaN
# 2019-08-01   NaN              NaN                 NaN
# 2019-09-01   NaN              NaN                 NaN
# 2019-10-01   NaN              NaN                 NaN
# 2019-11-01   NaN              NaN                 NaN
# 2019-12-01   NaN              NaN                 NaN
# 2020-01-01   NaN              NaN                 NaN
# 2020-02-01   NaN              NaN                 NaN
#
#            Seasonal First Difference forecast
# 2018-04-01                       NaN      NaN
# 2018-05-01                       NaN      NaN
# 2018-06-01                       NaN      NaN
# 2018-07-01                       NaN      NaN
# 2018-08-01                       NaN      NaN
# 2018-09-01                       NaN      NaN
# 2018-10-01                       NaN      NaN
# 2018-11-01                       NaN      NaN
# 2018-12-01                       NaN      NaN
# 2019-01-01                       NaN      NaN
# 2019-02-01                       NaN      NaN
# 2019-03-01                       NaN      NaN
# 2019-04-01                       NaN      NaN
# 2019-05-01                       NaN      NaN
# 2019-06-01                       NaN      NaN
# 2019-07-01                       NaN      NaN
# 2019-08-01                       NaN      NaN
# 2019-09-01                       NaN      NaN
# 2019-10-01                       NaN      NaN
# 2019-11-01                       NaN      NaN
# 2019-12-01                       NaN      NaN
# 2020-01-01                       NaN      NaN
# 2020-02-01                       NaN      NaN

# %%
final_df = pd.concat([df,future_df])

# %%
final_df.head()
# Out:
#                  Close First Difference Seasonal Difference  \
# 2008-01-01   102.39962              NaN                 NaN
# 2008-02-01  108.852776         6.453156                 NaN
# 2008-03-01  110.076485         1.223709                 NaN
# 2008-04-01  115.391968         5.315483                 NaN
# 2008-05-01  123.738052         8.346085                 NaN
#
#            Seasonal First Difference forecast
# 2008-01-01                       NaN      NaN
# 2008-02-01                       NaN      NaN
# 2008-03-01                       NaN      NaN
# 2008-04-01                       NaN      NaN
# 2008-05-01                       NaN      NaN

# %%
final_df.tail()
# Out:
#            Close First Difference Seasonal Difference  \
# 2019-10-01   NaN              NaN                 NaN
# 2019-11-01   NaN              NaN                 NaN
# 2019-12-01   NaN              NaN                 NaN
# 2020-01-01   NaN              NaN                 NaN
# 2020-02-01   NaN              NaN                 NaN
#
#            Seasonal First Difference forecast
# 2019-10-01                       NaN      NaN
# 2019-11-01                       NaN      NaN
# 2019-12-01                       NaN      NaN
# 2020-01-01                       NaN      NaN
# 2020-02-01                       NaN      NaN

# %%
final_df.shape
# Out:
# (146, 5)

# %%
final_df['forecast'] = results.predict(start=122,end=146)

# %%
final_df.tail()
# Out:
#            Close First Difference Seasonal Difference  \
# 2019-10-01   NaN              NaN                 NaN
# 2019-11-01   NaN              NaN                 NaN
# 2019-12-01   NaN              NaN                 NaN
# 2020-01-01   NaN              NaN                 NaN
# 2020-02-01   NaN              NaN                 NaN
#
#            Seasonal First Difference    forecast
# 2019-10-01                       NaN  142.597573
# 2019-11-01                       NaN  142.308995
# 2019-12-01                       NaN  143.964754
# 2020-01-01                       NaN  146.131690
# 2020-02-01                       NaN  149.113162

# %%
final_df['Close'].plot(figsize=(10,8))
final_df['forecast'].plot()
# Out:
# <AxesSubplot:>

# %%
final_df[['Close','forecast']].plot(figsize=(10,8));
plt.title('IBM Forecast')
plt.savefig('future_forecast_IBM.png')

# %%
open_price = df['Close'][-1]
open_price
# Out:
# 146.68260192871094

# %%
no_of_shares = 200000/open_price
no_of_shares
# Out:
# 1363.4882213038586

# %%
final_price=final_df['forecast'][-1]
final_price
# Out:
# 149.1131619408101

# %%
price_diff = final_price-open_price
price_diff
# Out:
# 2.430560012099164

# %%
P_L = price_diff*no_of_shares
P_L
# Out:
# 3314.039947669374
