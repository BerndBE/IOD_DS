# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import statsmodels.api as sm

# %%
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
df = yf.download('CSCO', 
                      start='2010-01-01', 
                      end='2021-10-01', 
                      progress=False, 
                      interval='1mo'
)
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close  \
# Date
# 2010-01-01  24.110001  25.100000  22.350000  22.469999  16.249784
# 2010-02-01  22.650000  24.459999  22.379999  24.330000  17.594894
# 2010-03-01  24.330000  26.850000  24.320000  26.030001  18.824297
# 2010-04-01  26.200001  27.740000  25.660000  26.930000  19.475155
# 2010-05-01  27.030001  27.690001  22.559999  23.160000  16.748779
#
#                   Volume
# Date
# 2010-01-01  9.309895e+08
# 2010-02-01  1.037381e+09
# 2010-03-01  1.169108e+09
# 2010-04-01  9.195802e+08
# 2010-05-01  1.443472e+09

# %%
df.drop(['Open','High','Low','Adj Close','Volume'],axis=1,inplace=True)
df.head()
# Out:
#                 Close
# Date
# 2010-01-01  22.469999
# 2010-02-01  24.330000
# 2010-03-01  26.030001
# 2010-04-01  26.930000
# 2010-05-01  23.160000

# %%
df.dropna(subset=['Close'],inplace=True)
df.head()
# Out:
#                 Close
# Date
# 2010-01-01  22.469999
# 2010-02-01  24.330000
# 2010-03-01  26.030001
# 2010-04-01  26.930000
# 2010-05-01  23.160000

# %%
df.tail()
# Out:
#                 Close
# Date
# 2021-05-01  52.900002
# 2021-06-01  53.000000
# 2021-07-01  55.369999
# 2021-08-01  59.020000
# 2021-09-01  54.430000

# %%
df.index
# Out:
# DatetimeIndex(['2010-01-01', '2010-02-01', '2010-03-01', '2010-04-01',
#                '2010-05-01', '2010-06-01', '2010-07-01', '2010-08-01',
#                '2010-09-01', '2010-10-01',
#                ...
#                '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01',
#                '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01',
#                '2021-08-01', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=141, freq=None)

# %%
df.describe().T
# Out:
#        count       mean        std   min    25%    50%        75%    max
# Close  141.0  31.751277  11.880406  15.5  21.91  28.42  42.889999  59.02

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
time_series = df['Close']

# %%
type(time_series)
# Out:
# pandas.core.series.Series

# %%
time_series.rolling(12).mean().plot(label='12 Month Rolling Mean',figsize=(10,8))
time_series.rolling(12).std().plot(label='12 Month Rolling STD')
time_series.plot(label='Milk in Pounds per Cow')
plt.legend();

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomp = seasonal_decompose(time_series)

# %%
fig=decomp.plot()
fig.set_size_inches(15,8)

# %%
df.head()
# Out:
#                 Close
# Date
# 2010-01-01  22.469999
# 2010-02-01  24.330000
# 2010-03-01  26.030001
# 2010-04-01  26.930000
# 2010-05-01  23.160000

# %% [markdown]
# ### Dicky Fuller Test
# Test if data is stationary or not

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(df['Close'])

# %%
result
# Out:
# (-0.5262757019526819,
#  0.886786177688867,
#  0,
#  140,
#  {'1%': -3.4779446621720114,
#   '5%': -2.8824156122448983,
#   '10%': -2.577901887755102},
#  578.3745961831657)

# %%
def adf_check(time_series):
    
    result=adfuller(time_series)
    print(" Augmented Dicky-Fuller Test")
    labels = ['ADF Test Statistic','p-value','# of lags','Num of Obseravtions used']
    
    for value,label in zip(result,labels):
        print(label+" : "+str(value))
        
    if result[1]<=0.05:
        print("Strong evidence against null hypothesis")
        print("Reject null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against null hypothesis")
        print("Fail to reject null hypothesis")
        print("Data has a unit root, it is non-stationary")

# %%
adf_check(df['Close'])
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -0.5262757019526819
# p-value : 0.886786177688867
# # of lags : 0
# Num of Obseravtions used : 140
# Weak evidence against null hypothesis
# Fail to reject null hypothesis
# Data has a unit root, it is non-stationary

# %%
df['First Difference'] = df['Close'] - df['Close'].shift(1)

# %%
df['First Difference'].plot();

# %%
adf_check(df['First Difference'].dropna())
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -12.96286592783403
# p-value : 3.1981103966696198e-24
# # of lags : 0
# Num of Obseravtions used : 139
# Strong evidence against null hypothesis
# Reject null hypothesis
# Data has no unit root and is stationary

# %%
df['Second Difference'] = df['First Difference'] - df['First Difference'].shift(1)

# %%
adf_check(df['Second Difference'].dropna())
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -5.832116080847869
# p-value : 3.952869677753607e-07
# # of lags : 12
# Num of Obseravtions used : 126
# Strong evidence against null hypothesis
# Reject null hypothesis
# Data has no unit root and is stationary

# %%
df['Second Difference'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### The above shows the data is stationary as p-value is < 0.05
# The below is just to show in case we need a second difference

# %%
df['Seasonal Difference'] = df['Close'] - df['Close'].shift(12)

# %%
df['Seasonal Difference'].plot();

# %%
adf_check(df['Seasonal Difference'].dropna())
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -2.5869944976258568
# p-value : 0.09571514270869375
# # of lags : 12
# Num of Obseravtions used : 116
# Weak evidence against null hypothesis
# Fail to reject null hypothesis
# Data has a unit root, it is non-stationary

# %%
df['Seasonal First Difference'] = df['First Difference'] - df['First Difference'].shift(12)

# %%
df['Seasonal Difference'].plot();

# %%
adf_check(df['Seasonal First Difference'].dropna())
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -4.44765045730581
# p-value : 0.0002442064609363735
# # of lags : 12
# Num of Obseravtions used : 115
# Strong evidence against null hypothesis
# Reject null hypothesis
# Data has no unit root and is stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
fig_first = plot_acf(df['First Difference'].dropna())

# %%
fig_seasonal_first = plot_acf(df['Seasonal First Difference'].dropna())

# %%
result = plot_pacf(df['Seasonal First Difference'].dropna())
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
plot_acf(df['Seasonal First Difference'].dropna())
plot_pacf(df['Seasonal First Difference'].dropna())
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
help(ARIMA)
# Out:
# Help on class ARIMA in module statsmodels.tsa.arima_model:
#
# class ARIMA(ARMA)
#  |  ARIMA(*args, **kwargs)
#  |
#  |  ARIMA has been deprecated in favor of the new implementation
#  |
#  |  See Also
#  |  --------
#  |  statsmodels.tsa.arima.model.ARIMA
#  |      ARIMA models with a variety of parameter estimators
#  |  statsmodels.tsa.statespace.SARIMAX
#  |      SARIMAX models estimated using MLE
#  |
#  |  Method resolution order:
#  |      ARIMA
#  |      ARMA
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from ARMA:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
model = sm.tsa.statespace.SARIMAX(df['Close'],order=(1,1,0),seasonal_order=(1,1,1,12))
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:536: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:536: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
results = model.fit()

# %%
print(results.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                Close   No. Observations:                  141
# Model:             SARIMAX(1, 1, 0)x(1, 1, [1], 12)   Log Likelihood                -307.922
# Date:                              Thu, 14 Apr 2022   AIC                            623.844
# Time:                                      12:06:14   BIC                            635.253
# Sample:                                  01-01-2010   HQIC                           628.480
#                                        - 09-01-2021
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1179      0.099     -1.185      0.236      -0.313       0.077
# ar.S.L12      -0.0328      0.110     -0.297      0.767      -0.249       0.184
# ma.S.L12      -0.9994     28.923     -0.035      0.972     -57.688      55.690
# sigma2         5.6857    164.172      0.035      0.972    -316.086     327.457
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):                12.52
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.88   Skew:                            -0.25
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.45
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
results.resid
# Out:
# Date
# 2010-01-01    22.469999
# 2010-02-01     1.860016
# 2010-03-01     1.700002
# 2010-04-01     0.900002
# 2010-05-01    -3.769999
#                 ...
# 2021-05-01     2.396868
# 2021-06-01     0.576713
# 2021-07-01     1.869717
# 2021-08-01     4.781055
# 2021-09-01    -4.598916
# Length: 141, dtype: float64

# %%
results.resid.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
results.resid.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.shape
# Out:
# (141, 5)

# %%
df['forecast'] = results.predict(start=130,end=141)
df[['Close','forecast']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.tail()
# Out:
#                 Close  First Difference  Second Difference  \
# Date
# 2021-05-01  52.900002          1.990002           2.790001
# 2021-06-01  53.000000          0.099998          -1.890003
# 2021-07-01  55.369999          2.369999           2.270000
# 2021-08-01  59.020000          3.650002           1.280003
# 2021-09-01  54.430000         -4.590000          -8.240002
#
#             Seasonal Difference  Seasonal First Difference   forecast
# Date
# 2021-05-01             5.080002                  -3.449997  50.503133
# 2021-06-01             6.360001                   1.279999  52.423287
# 2021-07-01             8.270000                   1.910000  53.500282
# 2021-08-01            16.799999                   8.529999  54.238945
# 2021-09-01            15.040001                  -1.759998  59.028916

# %%
from pandas.tseries.offsets import DateOffset

# %%
future_dates = [df.index[-1]+DateOffset(months=x) for x in range(1,24)]

# %%
future_dates
# Out:
# [Timestamp('2021-10-01 00:00:00'),
#  Timestamp('2021-11-01 00:00:00'),
#  Timestamp('2021-12-01 00:00:00'),
#  Timestamp('2022-01-01 00:00:00'),
#  Timestamp('2022-02-01 00:00:00'),
#  Timestamp('2022-03-01 00:00:00'),
#  Timestamp('2022-04-01 00:00:00'),
#  Timestamp('2022-05-01 00:00:00'),
#  Timestamp('2022-06-01 00:00:00'),
#  Timestamp('2022-07-01 00:00:00'),
#  Timestamp('2022-08-01 00:00:00'),
#  Timestamp('2022-09-01 00:00:00'),
#  Timestamp('2022-10-01 00:00:00'),
#  Timestamp('2022-11-01 00:00:00'),
#  Timestamp('2022-12-01 00:00:00'),
#  Timestamp('2023-01-01 00:00:00'),
#  Timestamp('2023-02-01 00:00:00'),
#  Timestamp('2023-03-01 00:00:00'),
#  Timestamp('2023-04-01 00:00:00'),
#  Timestamp('2023-05-01 00:00:00'),
#  Timestamp('2023-06-01 00:00:00'),
#  Timestamp('2023-07-01 00:00:00'),
#  Timestamp('2023-08-01 00:00:00')]

# %%
future_df = pd.DataFrame(index=future_dates,columns=df.columns)

# %%
future_df
# Out:
#            Close First Difference Second Difference Seasonal Difference  \
# 2021-10-01   NaN              NaN               NaN                 NaN
# 2021-11-01   NaN              NaN               NaN                 NaN
# 2021-12-01   NaN              NaN               NaN                 NaN
# 2022-01-01   NaN              NaN               NaN                 NaN
# 2022-02-01   NaN              NaN               NaN                 NaN
# 2022-03-01   NaN              NaN               NaN                 NaN
# 2022-04-01   NaN              NaN               NaN                 NaN
# 2022-05-01   NaN              NaN               NaN                 NaN
# 2022-06-01   NaN              NaN               NaN                 NaN
# 2022-07-01   NaN              NaN               NaN                 NaN
# 2022-08-01   NaN              NaN               NaN                 NaN
# 2022-09-01   NaN              NaN               NaN                 NaN
# 2022-10-01   NaN              NaN               NaN                 NaN
# 2022-11-01   NaN              NaN               NaN                 NaN
# 2022-12-01   NaN              NaN               NaN                 NaN
# 2023-01-01   NaN              NaN               NaN                 NaN
# 2023-02-01   NaN              NaN               NaN                 NaN
# 2023-03-01   NaN              NaN               NaN                 NaN
# 2023-04-01   NaN              NaN               NaN                 NaN
# 2023-05-01   NaN              NaN               NaN                 NaN
# 2023-06-01   NaN              NaN               NaN                 NaN
# 2023-07-01   NaN              NaN               NaN                 NaN
# 2023-08-01   NaN              NaN               NaN                 NaN
#
#            Seasonal First Difference forecast
# 2021-10-01                       NaN      NaN
# 2021-11-01                       NaN      NaN
# 2021-12-01                       NaN      NaN
# 2022-01-01                       NaN      NaN
# 2022-02-01                       NaN      NaN
# 2022-03-01                       NaN      NaN
# 2022-04-01                       NaN      NaN
# 2022-05-01                       NaN      NaN
# 2022-06-01                       NaN      NaN
# 2022-07-01                       NaN      NaN
# 2022-08-01                       NaN      NaN
# 2022-09-01                       NaN      NaN
# 2022-10-01                       NaN      NaN
# 2022-11-01                       NaN      NaN
# 2022-12-01                       NaN      NaN
# 2023-01-01                       NaN      NaN
# 2023-02-01                       NaN      NaN
# 2023-03-01                       NaN      NaN
# 2023-04-01                       NaN      NaN
# 2023-05-01                       NaN      NaN
# 2023-06-01                       NaN      NaN
# 2023-07-01                       NaN      NaN
# 2023-08-01                       NaN      NaN

# %%
final_df = pd.concat([df,future_df])

# %%
final_df.head()
# Out:
#                 Close First Difference Second Difference Seasonal Difference  \
# 2010-01-01  22.469999              NaN               NaN                 NaN
# 2010-02-01      24.33         1.860001               NaN                 NaN
# 2010-03-01  26.030001         1.700001             -0.16                 NaN
# 2010-04-01      26.93              0.9         -0.800001                 NaN
# 2010-05-01      23.16            -3.77             -4.67                 NaN
#
#            Seasonal First Difference forecast
# 2010-01-01                       NaN      NaN
# 2010-02-01                       NaN      NaN
# 2010-03-01                       NaN      NaN
# 2010-04-01                       NaN      NaN
# 2010-05-01                       NaN      NaN

# %%
final_df.tail()
# Out:
#            Close First Difference Second Difference Seasonal Difference  \
# 2023-04-01   NaN              NaN               NaN                 NaN
# 2023-05-01   NaN              NaN               NaN                 NaN
# 2023-06-01   NaN              NaN               NaN                 NaN
# 2023-07-01   NaN              NaN               NaN                 NaN
# 2023-08-01   NaN              NaN               NaN                 NaN
#
#            Seasonal First Difference forecast
# 2023-04-01                       NaN      NaN
# 2023-05-01                       NaN      NaN
# 2023-06-01                       NaN      NaN
# 2023-07-01                       NaN      NaN
# 2023-08-01                       NaN      NaN

# %%
final_df.shape
# Out:
# (164, 6)

# %%
final_df['forecast'] = results.predict(start=141,end=164)

# %%
final_df.tail()
# Out:
#            Close First Difference Second Difference Seasonal Difference  \
# 2023-04-01   NaN              NaN               NaN                 NaN
# 2023-05-01   NaN              NaN               NaN                 NaN
# 2023-06-01   NaN              NaN               NaN                 NaN
# 2023-07-01   NaN              NaN               NaN                 NaN
# 2023-08-01   NaN              NaN               NaN                 NaN
#
#            Seasonal First Difference   forecast
# 2023-04-01                       NaN  60.341238
# 2023-05-01                       NaN  60.165672
# 2023-06-01                       NaN  59.982134
# 2023-07-01                       NaN  60.663290
# 2023-08-01                       NaN  59.997878

# %%
final_df['Close'].plot(figsize=(10,8))
final_df['forecast'].plot()
# Out:
# <AxesSubplot:>

# %%
final_df[['Close','forecast']].plot(figsize=(10,8));

# %%
final_df['forecast']['2021-11-01']
# Out:
# 55.033091886150245
