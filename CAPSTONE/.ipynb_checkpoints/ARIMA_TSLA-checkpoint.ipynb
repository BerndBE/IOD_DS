# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import statsmodels.api as sm

# %%
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
df = yf.download('AAPL', 
                      start='2019-01-01', 
                      end='2021-10-01', 
                      progress=False, 
)
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-12-31  39.632500  39.840000  39.119999  39.435001  38.233898  140014000
# 2019-01-02  38.722500  39.712502  38.557499  39.480000  38.277523  148158800
# 2019-01-03  35.994999  36.430000  35.500000  35.547501  34.464802  365248800
# 2019-01-04  36.132500  37.137501  35.950001  37.064999  35.936081  234428400
# 2019-01-07  37.174999  37.207500  36.474998  36.982498  35.856102  219111200

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-09-24  145.660004  147.470001  145.559998  146.919998  146.519211
# 2021-09-27  145.470001  145.960007  143.820007  145.369995  144.973434
# 2021-09-28  143.250000  144.750000  141.690002  141.910004  141.522873
# 2021-09-29  142.470001  144.449997  142.029999  142.830002  142.440384
# 2021-09-30  143.660004  144.380005  141.279999  141.500000  141.113998
#
#                Volume
# Date
# 2021-09-24   53477900
# 2021-09-27   74150700
# 2021-09-28  108972300
# 2021-09-29   74602000
# 2021-09-30   89056700

# %%
df.index
# Out:
# DatetimeIndex(['2018-12-31', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10',
#                '2019-01-11', '2019-01-14',
#                ...
#                '2021-09-17', '2021-09-20', '2021-09-21', '2021-09-22',
#                '2021-09-23', '2021-09-24', '2021-09-27', '2021-09-28',
#                '2021-09-29', '2021-09-30'],
#               dtype='datetime64[ns]', name='Date', length=694, freq=None)

# %%
df.describe().T
# Out:
#            count          mean           std           min           25%  \
# Open       694.0  9.028213e+01  3.638161e+01  3.599500e+01  5.380875e+01
# High       694.0  9.132842e+01  3.672730e+01  3.643000e+01  5.462062e+01
# Low        694.0  8.926040e+01  3.590108e+01  3.550000e+01  5.297750e+01
# Close      694.0  9.034196e+01  3.630501e+01  3.554750e+01  5.370062e+01
# Adj Close  694.0  8.938673e+01  3.647786e+01  3.446480e+01  5.268911e+01
# Volume     694.0  1.230117e+08  5.844474e+07  4.544800e+07  8.456828e+07
#
#                     50%           75%           max
# Open       8.021000e+01  1.250000e+02  1.569800e+02
# High       8.091750e+01  1.264119e+02  1.572600e+02
# Low        7.952625e+01  1.238456e+02  1.543900e+02
# Close      8.021875e+01  1.251050e+02  1.566900e+02
# Adj Close  7.903755e+01  1.245099e+02  1.562626e+02
# Volume     1.078990e+08  1.430145e+08  4.265100e+08

# %%
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
time_series = df['Close']

# %%
type(time_series)
# Out:
# pandas.core.series.Series

# %%
time_series.rolling(12).mean().plot(label='12 Month Rolling Mean',figsize=(10,8))
time_series.rolling(12).std().plot(label='12 Month Rolling STD')
time_series.plot(label='Milk in Pounds per Cow')
plt.legend();

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomp = seasonal_decompose(time_series,period=30)

# %%
fig=decomp.plot()
fig.set_size_inches(15,8)

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-12-31  39.632500  39.840000  39.119999  39.435001  38.233898  140014000
# 2019-01-02  38.722500  39.712502  38.557499  39.480000  38.277523  148158800
# 2019-01-03  35.994999  36.430000  35.500000  35.547501  34.464802  365248800
# 2019-01-04  36.132500  37.137501  35.950001  37.064999  35.936081  234428400
# 2019-01-07  37.174999  37.207500  36.474998  36.982498  35.856102  219111200

# %% [markdown]
# ### Dicky Fuller Test
# Test if data is stationary or not

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(df['Close'])

# %%
result
# Out:
# (-0.6253597511717164,
#  0.8651481897297841,
#  1,
#  692,
#  {'1%': -3.439835148993393,
#   '5%': -2.865725696693157,
#   '10%': -2.568998987353403},
#  2836.7862210205135)

# %%
def adf_check(time_series):
    
    result=adfuller(time_series)
    print(" Augmented Dicky-Fuller Test")
    labels = ['ADF Test Statistic','p-value','# of lags','Num of Obseravtions used']
    
    for value,label in zip(result,labels):
        print(label+" : "+str(value))
        
    if result[1]<=0.05:
        print("Strong evidence against null hypothesis")
        print("Reject null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against null hypothesis")
        print("Fail to reject null hypothesis")
        print("Data has a unit root, it is non-stationary")

# %%
adf_check(df['Close'])
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -0.6253597511717164
# p-value : 0.8651481897297841
# # of lags : 1
# Num of Obseravtions used : 692
# Weak evidence against null hypothesis
# Fail to reject null hypothesis
# Data has a unit root, it is non-stationary

# %%
df['First Difference'] = df['Close'] - df['Close'].shift()

# %%
df['First Difference'].plot();

# %%
adf_check(df['First Difference'].dropna())
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -29.682465090099125
# p-value : 0.0
# # of lags : 0
# Num of Obseravtions used : 692
# Strong evidence against null hypothesis
# Reject null hypothesis
# Data has no unit root and is stationary

# %% [markdown]
# #### The above shows the data is stationary as p-value is < 0.05

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
fig_first = plot_acf(df['First Difference'].dropna())

# %%
result = plot_pacf(df['First Difference'].dropna())
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
plot_acf(df['First Difference'].dropna())
plot_pacf(df['First Difference'].dropna())
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
help(ARIMA)
# Out:
# Help on class ARIMA in module statsmodels.tsa.arima_model:
#
# class ARIMA(ARMA)
#  |  ARIMA(*args, **kwargs)
#  |
#  |  ARIMA has been deprecated in favor of the new implementation
#  |
#  |  See Also
#  |  --------
#  |  statsmodels.tsa.arima.model.ARIMA
#  |      ARIMA models with a variety of parameter estimators
#  |  statsmodels.tsa.statespace.SARIMAX
#  |      SARIMAX models estimated using MLE
#  |
#  |  Method resolution order:
#  |      ARIMA
#  |      ARMA
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from ARMA:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.arima_model import ARMA
from pmdarima.arima import auto_arima

# %%
model_autoARIMA = auto_arima(time_series, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(16,9))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2916.841, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2908.472, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2908.970, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2918.668, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2910.106, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2909.817, Time=0.16 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2911.785, Time=0.47 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=2911.344, Time=0.05 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0] intercept
# Total fit time: 0.982 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  694
# Model:               SARIMAX(1, 1, 0)   Log Likelihood               -1451.236
# Date:                Tue, 12 Apr 2022   AIC                           2908.472
# Time:                        13:28:49   BIC                           2922.095
# Sample:                             0   HQIC                          2913.740
#                                 - 694
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.1655      0.075      2.204      0.028       0.018       0.313
# ar.L1         -0.1218      0.027     -4.497      0.000      -0.175      -0.069
# sigma2         3.8588      0.118     32.596      0.000       3.627       4.091
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               524.62
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               7.28   Skew:                            -0.24
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#Modeling
# Build Model
from statsmodels.tsa.arima.model import ARIMA
from pmdarima.arima import auto_arima
model = ARIMA(df['Close'], order=(1, 1, 0))  
results = model.fit()  
print(results.summary())
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:593: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:593: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:593: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  694
# Model:                 ARIMA(1, 1, 0)   Log Likelihood               -1453.672
# Date:                Tue, 12 Apr 2022   AIC                           2911.344
# Time:                        13:28:50   BIC                           2920.426
# Sample:                             0   HQIC                          2914.856
#                                 - 694
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1156      0.027     -4.270      0.000      -0.169      -0.063
# sigma2         3.8861      0.120     32.392      0.000       3.651       4.121
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               522.77
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               7.12   Skew:                            -0.24
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
results.resid
# Out:
# Date
# 2018-12-31    39.435001
# 2019-01-02     0.045016
# 2019-01-03    -3.927299
# 2019-01-04     1.063075
# 2019-01-07     0.092855
#                 ...
# 2021-09-24     0.203241
# 2021-09-27    -1.539603
# 2021-09-28    -3.639103
# 2021-09-29     0.520176
# 2021-09-30    -1.223691
# Length: 694, dtype: float64

# %%
results.resid.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
results.resid.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.shape
# Out:
# (694, 7)

# %%
df['forecast'] = results.predict(start=670,end=693)
df[['Close','forecast']].plot(figsize=(15,12))
plt.legend(loc='upper left')

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-09-24  145.660004  147.470001  145.559998  146.919998  146.519211
# 2021-09-27  145.470001  145.960007  143.820007  145.369995  144.973434
# 2021-09-28  143.250000  144.750000  141.690002  141.910004  141.522873
# 2021-09-29  142.470001  144.449997  142.029999  142.830002  142.440384
# 2021-09-30  143.660004  144.380005  141.279999  141.500000  141.113998
#
#                Volume  First Difference    forecast
# Date
# 2021-09-24   53477900          0.089996  146.716758
# 2021-09-27   74150700         -1.550003  146.909599
# 2021-09-28  108972300         -3.459991  145.549107
# 2021-09-29   74602000          0.919998  142.309826
# 2021-09-30   89056700         -1.330002  142.723691

# %%
from pandas.tseries.offsets import DateOffset

# %%
future_dates = [df.index[-1]+DateOffset(days=x) for x in range(1,8)]

# %%
future_dates
# Out:
# [Timestamp('2021-10-01 00:00:00'),
#  Timestamp('2021-10-02 00:00:00'),
#  Timestamp('2021-10-03 00:00:00'),
#  Timestamp('2021-10-04 00:00:00'),
#  Timestamp('2021-10-05 00:00:00'),
#  Timestamp('2021-10-06 00:00:00'),
#  Timestamp('2021-10-07 00:00:00')]

# %%
future_df = pd.DataFrame(index=future_dates,columns=df.columns)

# %%
future_df
# Out:
#            Open High  Low Close Adj Close Volume First Difference forecast
# 2021-10-01  NaN  NaN  NaN   NaN       NaN    NaN              NaN      NaN
# 2021-10-02  NaN  NaN  NaN   NaN       NaN    NaN              NaN      NaN
# 2021-10-03  NaN  NaN  NaN   NaN       NaN    NaN              NaN      NaN
# 2021-10-04  NaN  NaN  NaN   NaN       NaN    NaN              NaN      NaN
# 2021-10-05  NaN  NaN  NaN   NaN       NaN    NaN              NaN      NaN
# 2021-10-06  NaN  NaN  NaN   NaN       NaN    NaN              NaN      NaN
# 2021-10-07  NaN  NaN  NaN   NaN       NaN    NaN              NaN      NaN

# %%
final_df = pd.concat([df,future_df])

# %%
final_df = final_df.reset_index()

# %%
final_df.head()
# Out:
#        index       Open       High        Low      Close  Adj Close  \
# 0 2018-12-31    39.6325      39.84  39.119999  39.435001  38.233898
# 1 2019-01-02    38.7225  39.712502  38.557499      39.48  38.277523
# 2 2019-01-03  35.994999      36.43       35.5  35.547501  34.464802
# 3 2019-01-04    36.1325  37.137501  35.950001  37.064999  35.936081
# 4 2019-01-07  37.174999    37.2075  36.474998  36.982498  35.856102
#
#       Volume First Difference forecast
# 0  140014000              NaN      NaN
# 1  148158800         0.044998      NaN
# 2  365248800        -3.932499      NaN
# 3  234428400         1.517498      NaN
# 4  219111200          -0.0825      NaN

# %%
final_df.tail()
# Out:
#          index Open High  Low Close Adj Close Volume First Difference forecast
# 696 2021-10-03  NaN  NaN  NaN   NaN       NaN    NaN              NaN      NaN
# 697 2021-10-04  NaN  NaN  NaN   NaN       NaN    NaN              NaN      NaN
# 698 2021-10-05  NaN  NaN  NaN   NaN       NaN    NaN              NaN      NaN
# 699 2021-10-06  NaN  NaN  NaN   NaN       NaN    NaN              NaN      NaN
# 700 2021-10-07  NaN  NaN  NaN   NaN       NaN    NaN              NaN      NaN

# %%
final_df.shape
# Out:
# (701, 9)

# %%
df.shape
# Out:
# (694, 8)

# %%
final_df['forecast'] = results.predict(start=694,end=701)
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:390: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'

# %%
final_df.tail(30)
# Out:
#          index        Open        High         Low       Close   Adj Close  \
# 671 2021-08-30       149.0  153.490005  148.610001  153.119995  152.702301
# 672 2021-08-31  152.660004  152.800003  151.289993  151.830002  151.415817
# 673 2021-09-01  152.830002  154.979996  152.339996  152.509995  152.093964
# 674 2021-09-02  153.869995  154.720001  152.399994  153.649994   153.23085
# 675 2021-09-03  153.759995  154.630005  153.089996  154.300003  153.879089
# 676 2021-09-07  154.970001  157.259995  154.389999  156.690002  156.262573
# 677 2021-09-08  156.979996  157.039993  153.979996  155.110001  154.686874
# 678 2021-09-09  155.490005  156.110001  153.949997  154.070007  153.649719
# 679 2021-09-10       155.0  155.479996  148.699997  148.970001  148.563614
# 680 2021-09-13  150.630005  151.419998      148.75  149.550003  149.142044
# 681 2021-09-14  150.350006  151.070007  146.910004  148.119995  147.715927
# 682 2021-09-15  148.559998  149.440002  146.369995  149.029999  148.623444
# 683 2021-09-16  148.440002  148.970001  147.220001  148.789993  148.384094
# 684 2021-09-17  148.820007  148.820007  145.759995  146.059998   145.66156
# 685 2021-09-20  143.800003  144.839996  141.270004  142.940002  142.550079
# 686 2021-09-21  143.929993  144.600006  142.779999  143.429993  143.038727
# 687 2021-09-22  144.449997  146.429993  143.699997  145.850006  145.452133
# 688 2021-09-23  146.649994  147.080002  145.639999  146.830002  146.429474
# 689 2021-09-24  145.660004  147.470001  145.559998  146.919998  146.519211
# 690 2021-09-27  145.470001  145.960007  143.820007  145.369995  144.973434
# 691 2021-09-28      143.25      144.75  141.690002  141.910004  141.522873
# 692 2021-09-29  142.470001  144.449997  142.029999  142.830002  142.440384
# 693 2021-09-30  143.660004  144.380005  141.279999       141.5  141.113998
# 694 2021-10-01         NaN         NaN         NaN         NaN         NaN
# 695 2021-10-02         NaN         NaN         NaN         NaN         NaN
# 696 2021-10-03         NaN         NaN         NaN         NaN         NaN
# 697 2021-10-04         NaN         NaN         NaN         NaN         NaN
# 698 2021-10-05         NaN         NaN         NaN         NaN         NaN
# 699 2021-10-06         NaN         NaN         NaN         NaN         NaN
# 700 2021-10-07         NaN         NaN         NaN         NaN         NaN
#
#         Volume First Difference    forecast
# 671   90956700         4.519989         NaN
# 672   86453100        -1.289993         NaN
# 673   80313700         0.679993         NaN
# 674   71115500         1.139999         NaN
# 675   57808700         0.650009         NaN
# 676   82278300         2.389999         NaN
# 677   74420200        -1.580002         NaN
# 678   57305700        -1.039993         NaN
# 679  140893200        -5.100006         NaN
# 680  102404300         0.580002         NaN
# 681  109296300        -1.430008         NaN
# 682   83281300         0.910004         NaN
# 683   68034100        -0.240005         NaN
# 684  129868800        -2.729996         NaN
# 685  123478900        -3.119995         NaN
# 686   75834000          0.48999         NaN
# 687   76404300         2.420013         NaN
# 688   64838200         0.979996         NaN
# 689   53477900         0.089996         NaN
# 690   74150700        -1.550003         NaN
# 691  108972300        -3.459991         NaN
# 692   74602000         0.919998         NaN
# 693   89056700        -1.330002         NaN
# 694        NaN              NaN  141.653690
# 695        NaN              NaN  141.635930
# 696        NaN              NaN  141.637982
# 697        NaN              NaN  141.637745
# 698        NaN              NaN  141.637772
# 699        NaN              NaN  141.637769
# 700        NaN              NaN  141.637770

# %%
final_df.head()
# Out:
#        index       Open       High        Low      Close  Adj Close  \
# 0 2018-12-31    39.6325      39.84  39.119999  39.435001  38.233898
# 1 2019-01-02    38.7225  39.712502  38.557499      39.48  38.277523
# 2 2019-01-03  35.994999      36.43       35.5  35.547501  34.464802
# 3 2019-01-04    36.1325  37.137501  35.950001  37.064999  35.936081
# 4 2019-01-07  37.174999    37.2075  36.474998  36.982498  35.856102
#
#       Volume First Difference  forecast
# 0  140014000              NaN       NaN
# 1  148158800         0.044998       NaN
# 2  365248800        -3.932499       NaN
# 3  234428400         1.517498       NaN
# 4  219111200          -0.0825       NaN

# %%
final_df['Close'].plot(figsize=(15,12))
final_df['forecast'].plot()
# Out:
# <AxesSubplot:>

# %%
final_df[['Close','forecast']].plot(figsize=(15,12));
