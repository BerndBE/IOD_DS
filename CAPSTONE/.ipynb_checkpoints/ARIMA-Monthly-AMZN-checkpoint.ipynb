# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import statsmodels.api as sm
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\compat\pandas.py:61: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
df = yf.download('AMZN', 
                      start='2010-01-01', 
                      end='2021-10-01', 
                      progress=False, 
                      interval='1mo'
)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-01  136.250000  136.610001  118.120003  125.410004  125.410004
# 2010-02-01  123.180000  124.860001  113.820000  118.400002  118.400002
# 2010-03-01  118.699997  138.190002  117.529999  135.770004  135.770004
# 2010-04-01  135.800003  151.089996  130.779999  137.100006  137.100006
# 2010-05-01  137.199997  139.440002  117.519997  125.459999  125.459999
#
#                Volume
# Date
# 2010-01-01  230861000
# 2010-02-01  210145800
# 2010-03-01  158042600
# 2010-04-01  173025100
# 2010-05-01  140909900

# %%
df.drop(['Open','High','Low','Adj Close','Volume'],axis=1,inplace=True)
df.head()
# Out:
#                  Close
# Date
# 2010-01-01  125.410004
# 2010-02-01  118.400002
# 2010-03-01  135.770004
# 2010-04-01  137.100006
# 2010-05-01  125.459999

# %%
df.dropna(subset=['Close'],inplace=True)
df.head()
# Out:
#                  Close
# Date
# 2010-01-01  125.410004
# 2010-02-01  118.400002
# 2010-03-01  135.770004
# 2010-04-01  137.100006
# 2010-05-01  125.459999

# %%
df.tail()
# Out:
#                   Close
# Date
# 2021-05-01  3223.070068
# 2021-06-01  3440.159912
# 2021-07-01  3327.590088
# 2021-08-01  3470.790039
# 2021-09-01  3285.040039

# %%
df.index
# Out:
# DatetimeIndex(['2010-01-01', '2010-02-01', '2010-03-01', '2010-04-01',
#                '2010-05-01', '2010-06-01', '2010-07-01', '2010-08-01',
#                '2010-09-01', '2010-10-01',
#                ...
#                '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01',
#                '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01',
#                '2021-08-01', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=141, freq=None)

# %%
df.describe().T
# Out:
#        count         mean         std         min         25%    50%  \
# Close  141.0  1023.620709  997.953197  109.260002  253.809998  587.0
#
#                75%          max
# Close  1699.800049  3470.790039

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
time_series = df['Close']

# %%
type(time_series)
# Out:
# pandas.core.series.Series

# %%
time_series.rolling(12).mean().plot(label='12 Month Rolling Mean',figsize=(10,8))
time_series.rolling(12).std().plot(label='12 Month Rolling STD')
time_series.plot(label='Milk in Pounds per Cow')
plt.legend();

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomp = seasonal_decompose(time_series)

# %%
fig=decomp.plot()
fig.set_size_inches(15,8)

# %%
df.head()
# Out:
#                  Close
# Date
# 2010-01-01  125.410004
# 2010-02-01  118.400002
# 2010-03-01  135.770004
# 2010-04-01  137.100006
# 2010-05-01  125.459999

# %% [markdown]
# ### Dicky Fuller Test
# Test if data is stationary or not

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(df['Close'])

# %%
result
# Out:
# (2.1618216556269947,
#  0.9988495937196492,
#  13,
#  127,
#  {'1%': -3.482920063655088,
#   '5%': -2.884580323367261,
#   '10%': -2.5790575441750883},
#  1553.2575482982209)

# %%
def adf_check(time_series):
    
    result=adfuller(time_series)
    print(" Augmented Dicky-Fuller Test")
    labels = ['ADF Test Statistic','p-value','# of lags','Num of Obseravtions used']
    
    for value,label in zip(result,labels):
        print(label+" : "+str(value))
        
    if result[1]<=0.05:
        print("Strong evidence against null hypothesis")
        print("Reject null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against null hypothesis")
        print("Fail to reject null hypothesis")
        print("Data has a unit root, it is non-stationary")

# %%
adf_check(df['Close'])
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : 2.1618216556269947
# p-value : 0.9988495937196492
# # of lags : 13
# Num of Obseravtions used : 127
# Weak evidence against null hypothesis
# Fail to reject null hypothesis
# Data has a unit root, it is non-stationary

# %%
df['First Difference'] = df['Close'] - df['Close'].shift(1)

# %%
df['First Difference'].plot();

# %%
adf_check(df['First Difference'].dropna())
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -3.09294303959871
# p-value : 0.0270798622253737
# # of lags : 12
# Num of Obseravtions used : 127
# Strong evidence against null hypothesis
# Reject null hypothesis
# Data has no unit root and is stationary

# %%
df['Second Difference'] = df['First Difference'] - df['First Difference'].shift(1)

# %%
adf_check(df['Second Difference'].dropna())
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -6.268720124468097
# p-value : 4.053559920425217e-08
# # of lags : 10
# Num of Obseravtions used : 128
# Strong evidence against null hypothesis
# Reject null hypothesis
# Data has no unit root and is stationary

# %%
df['Second Difference'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### The above shows the data is stationary as p-value is < 0.05
# The below is just to show in case we need a second difference

# %%
df['Seasonal Difference'] = df['Close'] - df['Close'].shift(12)

# %%
df['Seasonal Difference'].plot();

# %%
adf_check(df['Seasonal Difference'].dropna())
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -0.9590643031033076
# p-value : 0.7679004483109477
# # of lags : 12
# Num of Obseravtions used : 116
# Weak evidence against null hypothesis
# Fail to reject null hypothesis
# Data has a unit root, it is non-stationary

# %%
df['Seasonal First Difference'] = df['First Difference'] - df['First Difference'].shift(12)

# %%
df['Seasonal Difference'].plot();

# %%
adf_check(df['Seasonal First Difference'].dropna())
# Out:
#  Augmented Dicky-Fuller Test
# ADF Test Statistic : -6.883897112590809
# p-value : 1.410581771125347e-09
# # of lags : 11
# Num of Obseravtions used : 116
# Strong evidence against null hypothesis
# Reject null hypothesis
# Data has no unit root and is stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
fig_first = plot_acf(df['First Difference'].dropna())

# %%
fig_seasonal_first = plot_acf(df['Seasonal First Difference'].dropna())

# %%
result = plot_pacf(df['Seasonal First Difference'].dropna())
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
plot_acf(df['Seasonal First Difference'].dropna())
plot_pacf(df['Seasonal First Difference'].dropna())
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
help(ARIMA)
# Out:
# Help on class ARIMA in module statsmodels.tsa.arima_model:
#
# class ARIMA(ARMA)
#  |  ARIMA(*args, **kwargs)
#  |
#  |  ARIMA has been deprecated in favor of the new implementation
#  |
#  |  See Also
#  |  --------
#  |  statsmodels.tsa.arima.model.ARIMA
#  |      ARIMA models with a variety of parameter estimators
#  |  statsmodels.tsa.statespace.SARIMAX
#  |      SARIMAX models estimated using MLE
#  |
#  |  Method resolution order:
#  |      ARIMA
#  |      ARMA
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from ARMA:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
model = sm.tsa.statespace.SARIMAX(df['Close'],order=(0,1,0),seasonal_order=(1,1,1,12))
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:536: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\tsa\base\tsa_model.py:536: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
results = model.fit()
# Out:
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'

# %%
print(results.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                Close   No. Observations:                  141
# Model:             SARIMAX(0, 1, 0)x(1, 1, [1], 12)   Log Likelihood                -779.857
# Date:                              Thu, 14 Apr 2022   AIC                           1565.715
# Time:                                      12:45:37   BIC                           1574.271
# Sample:                                  01-01-2010   HQIC                          1569.191
#                                        - 09-01-2021
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12      -0.5809      0.149     -3.899      0.000      -0.873      -0.289
# ma.S.L12      -0.0670      0.192     -0.350      0.727      -0.443       0.309
# sigma2      1.097e+04    841.288     13.035      0.000    9317.134    1.26e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.84   Jarque-Bera (JB):               114.20
# Prob(Q):                              0.36   Prob(JB):                         0.00
# Heteroskedasticity (H):              51.66   Skew:                            -0.01
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
results.resid
# Out:
# Date
# 2010-01-01    125.410004
# 2010-02-01     -7.010002
# 2010-03-01     17.370003
# 2010-04-01      1.330002
# 2010-05-01    -11.640007
#                  ...
# 2021-05-01   -144.436050
# 2021-06-01     31.235390
# 2021-07-01   -242.442925
# 2021-08-01     87.592730
# 2021-09-01    -54.498012
# Length: 141, dtype: float64

# %%
results.resid.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
results.resid.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.shape
# Out:
# (141, 5)

# %%
df['forecast'] = results.predict(start=130,end=141)
df[['Close','forecast']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.tail()
# Out:
#                   Close  First Difference  Second Difference  \
# Date
# 2021-05-01  3223.070068       -244.349854        -617.689697
# 2021-06-01  3440.159912        217.089844         461.439697
# 2021-07-01  3327.590088       -112.569824        -329.659668
# 2021-08-01  3470.790039        143.199951         255.769775
# 2021-09-01  3285.040039       -185.750000        -328.949951
#
#             Seasonal Difference  Seasonal First Difference     forecast
# Date
# 2021-05-01           780.699951                -212.719971  3367.506118
# 2021-06-01           681.339844                 -99.360107  3408.924522
# 2021-07-01           162.910156                -518.429688  3570.033013
# 2021-08-01            19.830078                -143.080078  3383.197309
# 2021-09-01           136.310059                 116.479980  3339.538051

# %%
from pandas.tseries.offsets import DateOffset

# %%
future_dates = [df.index[-1]+DateOffset(months=x) for x in range(1,24)]

# %%
future_dates
# Out:
# [Timestamp('2021-10-01 00:00:00'),
#  Timestamp('2021-11-01 00:00:00'),
#  Timestamp('2021-12-01 00:00:00'),
#  Timestamp('2022-01-01 00:00:00'),
#  Timestamp('2022-02-01 00:00:00'),
#  Timestamp('2022-03-01 00:00:00'),
#  Timestamp('2022-04-01 00:00:00'),
#  Timestamp('2022-05-01 00:00:00'),
#  Timestamp('2022-06-01 00:00:00'),
#  Timestamp('2022-07-01 00:00:00'),
#  Timestamp('2022-08-01 00:00:00'),
#  Timestamp('2022-09-01 00:00:00'),
#  Timestamp('2022-10-01 00:00:00'),
#  Timestamp('2022-11-01 00:00:00'),
#  Timestamp('2022-12-01 00:00:00'),
#  Timestamp('2023-01-01 00:00:00'),
#  Timestamp('2023-02-01 00:00:00'),
#  Timestamp('2023-03-01 00:00:00'),
#  Timestamp('2023-04-01 00:00:00'),
#  Timestamp('2023-05-01 00:00:00'),
#  Timestamp('2023-06-01 00:00:00'),
#  Timestamp('2023-07-01 00:00:00'),
#  Timestamp('2023-08-01 00:00:00')]

# %%
future_df = pd.DataFrame(index=future_dates,columns=df.columns)

# %%
future_df
# Out:
#            Close First Difference Second Difference Seasonal Difference  \
# 2021-10-01   NaN              NaN               NaN                 NaN
# 2021-11-01   NaN              NaN               NaN                 NaN
# 2021-12-01   NaN              NaN               NaN                 NaN
# 2022-01-01   NaN              NaN               NaN                 NaN
# 2022-02-01   NaN              NaN               NaN                 NaN
# 2022-03-01   NaN              NaN               NaN                 NaN
# 2022-04-01   NaN              NaN               NaN                 NaN
# 2022-05-01   NaN              NaN               NaN                 NaN
# 2022-06-01   NaN              NaN               NaN                 NaN
# 2022-07-01   NaN              NaN               NaN                 NaN
# 2022-08-01   NaN              NaN               NaN                 NaN
# 2022-09-01   NaN              NaN               NaN                 NaN
# 2022-10-01   NaN              NaN               NaN                 NaN
# 2022-11-01   NaN              NaN               NaN                 NaN
# 2022-12-01   NaN              NaN               NaN                 NaN
# 2023-01-01   NaN              NaN               NaN                 NaN
# 2023-02-01   NaN              NaN               NaN                 NaN
# 2023-03-01   NaN              NaN               NaN                 NaN
# 2023-04-01   NaN              NaN               NaN                 NaN
# 2023-05-01   NaN              NaN               NaN                 NaN
# 2023-06-01   NaN              NaN               NaN                 NaN
# 2023-07-01   NaN              NaN               NaN                 NaN
# 2023-08-01   NaN              NaN               NaN                 NaN
#
#            Seasonal First Difference forecast
# 2021-10-01                       NaN      NaN
# 2021-11-01                       NaN      NaN
# 2021-12-01                       NaN      NaN
# 2022-01-01                       NaN      NaN
# 2022-02-01                       NaN      NaN
# 2022-03-01                       NaN      NaN
# 2022-04-01                       NaN      NaN
# 2022-05-01                       NaN      NaN
# 2022-06-01                       NaN      NaN
# 2022-07-01                       NaN      NaN
# 2022-08-01                       NaN      NaN
# 2022-09-01                       NaN      NaN
# 2022-10-01                       NaN      NaN
# 2022-11-01                       NaN      NaN
# 2022-12-01                       NaN      NaN
# 2023-01-01                       NaN      NaN
# 2023-02-01                       NaN      NaN
# 2023-03-01                       NaN      NaN
# 2023-04-01                       NaN      NaN
# 2023-05-01                       NaN      NaN
# 2023-06-01                       NaN      NaN
# 2023-07-01                       NaN      NaN
# 2023-08-01                       NaN      NaN

# %%
final_df = pd.concat([df,future_df])

# %%
final_df.head()
# Out:
#                  Close First Difference Second Difference Seasonal Difference  \
# 2010-01-01  125.410004              NaN               NaN                 NaN
# 2010-02-01  118.400002        -7.010002               NaN                 NaN
# 2010-03-01  135.770004        17.370003         24.380005                 NaN
# 2010-04-01  137.100006         1.330002        -16.040001                 NaN
# 2010-05-01  125.459999       -11.640007        -12.970009                 NaN
#
#            Seasonal First Difference forecast
# 2010-01-01                       NaN      NaN
# 2010-02-01                       NaN      NaN
# 2010-03-01                       NaN      NaN
# 2010-04-01                       NaN      NaN
# 2010-05-01                       NaN      NaN

# %%
final_df.tail()
# Out:
#            Close First Difference Second Difference Seasonal Difference  \
# 2023-04-01   NaN              NaN               NaN                 NaN
# 2023-05-01   NaN              NaN               NaN                 NaN
# 2023-06-01   NaN              NaN               NaN                 NaN
# 2023-07-01   NaN              NaN               NaN                 NaN
# 2023-08-01   NaN              NaN               NaN                 NaN
#
#            Seasonal First Difference forecast
# 2023-04-01                       NaN      NaN
# 2023-05-01                       NaN      NaN
# 2023-06-01                       NaN      NaN
# 2023-07-01                       NaN      NaN
# 2023-08-01                       NaN      NaN

# %%
final_df.shape
# Out:
# (164, 6)

# %%
final_df['forecast'] = results.predict(start=141,end=164)

# %%
final_df.tail()
# Out:
#            Close First Difference Second Difference Seasonal Difference  \
# 2023-04-01   NaN              NaN               NaN                 NaN
# 2023-05-01   NaN              NaN               NaN                 NaN
# 2023-06-01   NaN              NaN               NaN                 NaN
# 2023-07-01   NaN              NaN               NaN                 NaN
# 2023-08-01   NaN              NaN               NaN                 NaN
#
#            Seasonal First Difference     forecast
# 2023-04-01                       NaN  4597.646561
# 2023-05-01                       NaN  4409.141871
# 2023-06-01                       NaN  4649.544115
# 2023-07-01                       NaN  4669.999320
# 2023-08-01                       NaN  4845.572473

# %%
final_df['Close'].plot(figsize=(10,8))
final_df['forecast'].plot()
# Out:
# <AxesSubplot:>

# %%
final_df[['Close','forecast']].plot(figsize=(10,8));

# %%
final_df['forecast']['2021-11-01']
# Out:
# 3318.960824960697
