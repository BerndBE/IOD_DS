# %%
import pandas as pd
import numpy as np
import os
from subprocess import check_output
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from pandas.plotting import lag_plot
from pandas import datetime
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARMA
warnings.filterwarnings('ignore')

import warnings
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
# Out:
# C:\Users\Trader\AppData\Local\Temp\ipykernel_9700\804097999.py:9: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime
# C:\Users\Trader\anaconda3\envs\iod_dl\lib\site-packages\statsmodels\compat\pandas.py:61: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (1.8.5)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from pmdarima) (0.13.0)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from pmdarima) (1.22.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from pmdarima) (58.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from pmdarima) (0.17.0)
# Requirement already satisfied: pandas>=0.19 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: urllib3 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from pmdarima) (1.26.8)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from pmdarima) (0.29.28)
# Requirement already satisfied: pytz>=2020.1 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from pandas>=0.19->pmdarima) (2020.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.1.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\trader\anaconda3\envs\iod_dl\lib\site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
bhp = yf.Ticker("BHP.AX")

# %%
print(bhp.info)
# Out:
# {'zip': '3000', 'sector': 'Basic Materials', 'fullTimeEmployees': 40110, 'longBusinessSummary': 'BHP Group Limited operates as a resources company in Australia, Europe, China, Japan, India, South Korea, rest of Asia, North America, South America, and internationally. It operates through Petroleum, Copper, Iron Ore, and Coal segments. The company engages in the exploration, development, and production of oil and gas properties; and mining of copper, silver, zinc, molybdenum, uranium, gold, iron ore, and metallurgical and energy coal. It is also involved in mining, smelting, and refining of nickel; and potash development activities. In addition, the company provides towing, freight, marketing and trading, marketing support, finance, administrative, and other services. The company was founded in 1851 and is headquartered in Melbourne, Australia.', 'city': 'Melbourne', 'phone': '61 3 9609 3333', 'state': 'VIC', 'country': 'Australia', 'companyOfficers': [], 'website': 'https://www.bhp.com', 'maxAge': 1, 'address1': '171 Collins Street', 'fax': '61 3 9609 3015', 'industry': 'Other Industrial Metals & Mining', 'ebitdaMargins': 0.59266, 'profitMargins': 0.24855, 'grossMargins': 0.85185, 'operatingCashflow': 31142000640, 'revenueGrowth': 0.275, 'operatingMargins': 0.49609002, 'ebitda': 40228999168, 'targetLowPrice': 43.69, 'recommendationKey': 'buy', 'grossProfits': 54007000000, 'freeCashflow': 11234750464, 'targetMedianPrice': 48.65, 'currentPrice': 47.69, 'earningsGrowth': 1.433, 'currentRatio': 1.924, 'returnOnAssets': 0.20143999, 'numberOfAnalystOpinions': 15, 'targetMeanPrice': 49.6, 'debtToEquity': 36.089, 'returnOnEquity': 0.33163, 'targetHighPrice': 57.59, 'totalCash': 12551999488, 'totalDebt': 19821000704, 'totalRevenue': 67878998016, 'totalCashPerShare': 2.48, 'financialCurrency': 'USD', 'revenuePerShare': 13.417, 'quickRatio': 0.858, 'recommendationMean': 2.5, 'exchange': 'ASX', 'shortName': 'BHP GROUP FPO', 'longName': 'BHP Group Limited', 'exchangeTimezoneName': 'Australia/Sydney', 'exchangeTimezoneShortName': 'AEDT', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '39600000', 'quoteType': 'EQUITY', 'symbol': 'BHP.AX', 'messageBoardId': 'finmb_256654', 'market': 'au_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 3.786, 'beta3Year': None, 'enterpriseToEbitda': 6.389, '52WeekChange': -0.0058369637, 'morningStarRiskRating': None, 'forwardEps': 4.16, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 5062320128, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'totalAssets': None, 'bookValue': 10.035, 'sharesShort': None, 'sharesPercentSharesOut': None, 'fundFamily': None, 'lastFiscalYearEnd': 1625011200, 'heldPercentInstitutions': 0.20709999, 'netIncomeToCommon': 15706999808, 'trailingEps': 4.582, 'lastDividendValue': 2.080559, 'SandP52WeekChange': 0.080180764, 'priceToBook': 4.7523665, 'heldPercentInsiders': 0.0356, 'nextFiscalYearEnd': 1688083200, 'yield': None, 'mostRecentQuarter': 1640908800, 'shortRatio': None, 'sharesShortPreviousMonthDate': None, 'floatShares': 5047385910, 'beta': 0.775053, 'enterpriseValue': 257014333440, 'priceHint': 2, 'threeYearAverageReturn': None, 'lastSplitDate': 1025568000, 'lastSplitFactor': '1:1', 'legalType': None, 'lastDividendDate': 1645574400, 'morningStarOverallRating': None, 'earningsQuarterlyGrowth': 1.436, 'priceToSalesTrailing12Months': 5.0404816, 'dateShortInterest': None, 'pegRatio': -0.4, 'ytdReturn': None, 'forwardPE': 11.463943, 'lastCapGain': None, 'shortPercentOfFloat': None, 'sharesShortPriorMonth': None, 'impliedSharesOutstanding': 0, 'category': None, 'fiveYearAverageReturn': None, 'previousClose': 47.75, 'regularMarketOpen': 48.31, 'twoHundredDayAverage': 44.0934, 'trailingAnnualDividendYield': 0.07329843, 'payoutRatio': 0.96489996, 'volume24Hr': None, 'regularMarketDayHigh': 48.75, 'navPrice': None, 'averageDailyVolume10Day': 14078598, 'regularMarketPreviousClose': 47.75, 'fiftyDayAverage': 46.658, 'trailingAnnualDividendRate': 3.5, 'open ...

# %%
hist = bhp.history(period='1Y')

# %%
hist.head()
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2021-03-11  42.255545  42.426364  41.329520  42.075733  10072426        0.0
# 2021-03-12  43.199555  43.226529  42.687094  43.127632   4128891        0.0
# 2021-03-15  42.947822  43.217538  42.417380  43.046719   5006262        0.0
# 2021-03-16  42.363432  42.866904  42.102709  42.111698   6968502        0.0
# 2021-03-17  41.680156  41.877949  41.329526  41.419430   7261879        0.0
#
#             Stock Splits
# Date
# 2021-03-11             0
# 2021-03-12             0
# 2021-03-15             0
# 2021-03-16             0
# 2021-03-17             0

# %%
bhp = hist['Close']

# %%
bhp.head()
# Out:
# Date
# 2021-03-11    42.075733
# 2021-03-12    43.127632
# 2021-03-15    43.046719
# 2021-03-16    42.111698
# 2021-03-17    41.419430
# Name: Close, dtype: float64

# %%
bhp.tail()
# Out:
# Date
# 2022-03-07    50.380001
# 2022-03-08    48.529999
# 2022-03-09    48.490002
# 2022-03-10    47.750000
# 2022-03-11    47.689999
# Name: Close, dtype: float64

# %%
bhp.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 255 entries, 2021-03-11 to 2022-03-11
# Series name: Close
# Non-Null Count  Dtype
# --------------  -----
# 255 non-null    float64
# dtypes: float64(1)
# memory usage: 4.0 KB

# %%
bhp.shape
# Out:
# (255,)

# %%
sns.boxplot(bhp, color='g');

# %%
bhp.plot(label='BHP', figsize=(16, 9))
plt.xlabel('Month', fontsize=20)
plt.title('BHP Share Price', fontsize=20)
plt.ylabel('Share Price', fontsize=20)
plt.grid(True)
plt.legend()
plt.show()

# %%
df_close = bhp
df_close.plot(kind='kde', label='BHP-KDE', figsize=(16,9))
plt.legend()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
#Test for staionarity
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    #Plot rolling statistics:
    plt.figure(figsize=(16, 9))
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)
test_stationarity(bhp)
# Out:
# Results of dickey fuller test
# Test Statistics                 -1.280065
# p-value                          0.638243
# No. of lags used                 1.000000
# Number of observations used    253.000000
# critical value (1%)             -3.456464
# critical value (5%)             -2.873033
# critical value (10%)            -2.572895
# dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
#To separate the trend and the seasonality from a time series, 
# we can decompose the series using the following code.
result = seasonal_decompose(df_close, model='multiplicative', period = 30)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)
plt.show()

# %%
#if not stationary then eliminate trend
#Eliminate trend
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
df_log = np.log(df_close)
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#split data into train and training set
train_data, test_data = df_log[3:int(len(df_log)*0.9)], df_log[int(len(df_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_log, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %%
from pmdarima.arima import auto_arima

# %%
model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-1188.127, Time=0.15 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-1188.317, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-1188.627, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-1190.060, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-1187.028, Time=0.21 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.561 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  226
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                 596.030
# Date:                Fri, 11 Mar 2022   AIC                          -1190.060
# Time:                        22:14:09   BIC                          -1186.644
# Sample:                             0   HQIC                         -1188.681
#                                 - 226
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0003   2.04e-05     14.336      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.18   Jarque-Bera (JB):                39.71
# Prob(Q):                              0.14   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.40   Skew:                            -0.59
# Prob(H) (two-sided):                  0.14   Kurtosis:                         4.69
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#Modeling
# Build Model
model = ARIMA(train_data, order=(0,1,0))  
fitted = model.fit()  
print(fitted.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  226
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                 596.030
# Date:                Fri, 11 Mar 2022   AIC                          -1190.060
# Time:                        22:19:07   BIC                          -1186.644
# Sample:                             0   HQIC                         -1188.681
#                                 - 226
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0003   2.04e-05     14.336      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.18   Jarque-Bera (JB):                39.71
# Prob(Q):                              0.14   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.40   Skew:                            -0.59
# Prob(H) (two-sided):                  0.14   Kurtosis:                         4.69
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast
fc, se, conf = fitted.forecast(3, alpha=0.05)  # 95% conf

# %%
# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)
lower_series = pd.Series(conf[:, 0], index=test_data.index)
upper_series = pd.Series(conf[:, 1], index=test_data.index)
# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training data')
plt.plot(test_data, color = 'blue', label='Actual Stock Price')
plt.plot(fc_series, color = 'orange',label='Predicted Stock Price')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.10)
plt.title('ARCH CAPITAL GROUP Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('ARCH CAPITAL GROUP Stock Price')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [32], in <module>
#       1 # Make as pandas series
#       2 fc_series = pd.Series(fc, index=test_data.index)
# ----> 3 lower_series = pd.Series(conf[:, 0], index=test_data.index)
#       4 upper_series = pd.Series(conf[:, 1], index=test_data.index)
#       5 # Plot
#
# TypeError: 'float' object is not subscriptable

# %%
# report performance
mse = mean_squared_error(test_data, fc)
print('MSE: '+str(mse))
mae = mean_absolute_error(test_data, fc)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(test_data, fc))
print('RMSE: '+str(rmse))
mape = np.mean(np.abs(fc - test_data)/np.abs(test_data))
print('MAPE: '+str(mape))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [41], in <module>
#       1 # report performance
# ----> 2 mse = mean_squared_error(test_data, fc)
#       3 print('MSE: '+str(mse))
#       4 mae = mean_absolute_error(test_data, fc)
#
# File ~\anaconda3\envs\iod_dl\lib\site-packages\sklearn\metrics\_regression.py:438, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     378 def mean_squared_error(
#     379     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     380 ):
#     381     """Mean squared error regression loss.
#     382
#     383     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     436     0.825...
#     437     """
# --> 438     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     439         y_true, y_pred, multioutput
#     440     )
#     441     check_consistent_length(y_true, y_pred, sample_weight)
#     442     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~\anaconda3\envs\iod_dl\lib\site-packages\sklearn\metrics\_regression.py:94, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      60 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      61     """Check that y_true and y_pred belong to the same regression task.
#      62
#      63     Parameters
#    (...)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~\anaconda3\envs\iod_dl\lib\site-packages\sklearn\utils\validation.py:329, in check_consistent_length(*arrays)
#     318 def check_consistent_length(*arrays):
#     319     """Check that all arrays have consistent first dimensions.
#     320
#     321     Checks whether all objects in arrays have the same shape or length.
#    (...)
#     326         Objects that will be checked for consistent length.
#     327     """
# --> 329     lengths = [_num_samples(X) for X in arrays if X is not None]
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
#
# File ~\anaconda3\envs\iod_dl\lib\site-packages\sklearn\utils\validation.py:329, in <listcomp>(.0)
#     318 def check_consistent_length(*arrays):
#     319     """Check that all arrays have consistent first dimensions.
#     320
#     321     Checks whether all objects in arrays have the same shape or length.
#    (...)
#     326         Objects that will be checked for consistent length.
#     327     """
# --> 329     lengths = [_num_samples(X) for X in arrays if X is not None]
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
#
# File ~\anaconda3\envs\iod_dl\lib\site-packages\sklearn\utils\validation.py:265, in _num_samples(x)
#     263         x = np.asarray(x)
#     264     else:
# --> 265         raise TypeError(message)
#     267 if hasattr(x, "shape") and x.shape is not None:
#     268     if len(x.shape) == 0:
#
# TypeError: Expected sequence or array-like, got <class 'float'>

# %%
from platform import python_version

print(python_version())
# Out:
# 3.9.7
